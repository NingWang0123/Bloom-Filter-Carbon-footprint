# %%
import pandas as pd
import math
import numpy as np
import time
from codecarbon import EmissionsTracker
from Bloom_filter import BloomFilter
import PLBF
import disjoint_Ada_BF
import learned_Bloom_filter
import Ada_BF
from codecarbon import EmissionsTracker
from concurrent.futures import ThreadPoolExecutor
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
# Out:
# [codecarbon INFO @ 01:15:10] Energy consumed for RAM : 0.538906 kWh. RAM Power : 23.887279987335205 W
# [codecarbon INFO @ 01:15:10] Energy consumed for all GPUs : 0.477918 kWh. Total GPU Power : 18.38734630310346 W
# [codecarbon INFO @ 01:15:10] Energy consumed for all CPUs : 0.970916 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:15:10] 1.987740 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:15:13] Energy consumed for RAM : 0.539719 kWh. RAM Power : 23.887279987335205 W
# [codecarbon INFO @ 01:15:13] Energy consumed for all GPUs : 0.477342 kWh. Total GPU Power : 17.489458002579337 W
# [codecarbon INFO @ 01:15:13] Energy consumed for all CPUs : 0.971544 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:15:13] 1.988605 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:15:25] Energy consumed for RAM : 0.539005 kWh. RAM Power : 23.887279987335205 W
# [codecarbon INFO @ 01:15:25] Energy consumed for all GPUs : 0.478005 kWh. Total GPU Power : 20.86901207821127 W
# [codecarbon INFO @ 01:15:25] Energy consumed for all CPUs : 0.971093 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:15:25] 1.988104 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:15:28] Energy consumed for RAM : 0.539818 kWh. RAM Power : 23.887279987335205 W
# [codecarbon INFO @ 01:15:28] Energy consumed for all GPUs : 0.477464 kWh. Total GPU Power : 29.23894153449506 W
# [codecarbon INFO @ 01:15:28] Energy consumed for all CPUs : 0.971721 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:15:28] 1.989004 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:15:40] Energy consumed for RAM : 0.539105 kWh. RAM Power : 23.887279987335205 W
# [codecarbon INFO @ 01:15:40] Energy consumed for all GPUs : 0.478123 kWh. Total GPU Power : 28.211588780092388 W
# [codecarbon INFO @ 01:15:40] Energy consumed for all CPUs : 0.971271 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:15:40] 1.988498 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:15:43] Energy consumed for RAM : 0.539918 kWh. RAM Power : 23.887279987335205 W
# [codecarbon INFO @ 01:15:43] Energy consumed for all GPUs : 0.477548 kWh. Total GPU Power : 20.145068671089557 W
# [codecarbon INFO @ 01:15:43] Energy consumed for all CPUs : 0.971898 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:15:43] 1.989365 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:15:55] Energy consumed for RAM : 0.539204 kWh. RAM Power : 23.887279987335205 W
# [codecarbon INFO @ 01:15:55] Energy consumed for all GPUs : 0.478205 kWh. Total GPU Power : 19.813214151860723 W
# [codecarbon INFO @ 01:15:55] Energy consumed for all CPUs : 0.971448 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:15:55] 1.988857 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:15:58] Energy consumed for RAM : 0.540018 kWh. RAM Power : 23.887279987335205 W
# [codecarbon INFO @ 01:15:58] Energy consumed for all GPUs : 0.477632 kWh. Total GPU Power : 20.010169788399878 W
# [codecarbon INFO @ 01:15:58] Energy consumed for all CPUs : 0.972076 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:15:58] 1.989725 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:16:10] Energy consumed for RAM : 0.539304 kWh. RAM Power : 23.887279987335205 W
# [codecarbon INFO @ 01:16:10] Energy consumed for all GPUs : 0.478286 kWh. Total GPU Power : 19.236422750740836 W
# [codecarbon INFO @ 01:16:10] Energy consumed for all CPUs : 0.971625 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:16:10] 1.989214 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:16:13] Energy consumed for RAM : 0.540117 kWh. RAM Power : 23.887279987335205 W
# [codecarbon INFO @ 01:16:13] Energy consumed for all GPUs : 0.477710 kWh. Total GPU Power : 18.734585278104415 W
# [codecarbon INFO @ 01:16:13] Energy consumed for all CPUs : 0.972253 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:16:13] 1.990080 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:16:25] Energy consumed for RAM : 0.539403 kWh. RAM Power : 23.887279987335205 W
# [codecarbon INFO @ 01:16:25] Energy consumed for all GPUs : 0.478415 kWh. Total GPU Power : 30.975791534639903 W
# [codecarbon INFO @ 01:16:25] Energy consumed for all CPUs : 0.971802 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:16:25] 1.989620 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:16:28] Energy consumed for RAM : 0.540217 kWh. RAM Power : 23.887279987335205 W
# [codecarbon INFO @ 01:16:28] Energy consumed for all GPUs : 0.477844 kWh. Total GPU Power : 32.29816542328139 W
# [codecarbon INFO @ 01:16:28] Energy consumed for all CPUs : 0.972430 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:16:28] 1.990491 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:16:40] Energy consumed for RAM : 0.539503 kWh. RAM Power : 23.887279987335205 W
# [codecarbon INFO @ 01:16:40] Energy consumed for all GPUs : 0.478509 kWh. Total GPU Power : 22.73481369291753 W
# [codecarbon INFO @ 01:16:40] Energy consumed for all CPUs : 0.971979 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:16:40] 1.989991 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:16:43] Energy consumed for RAM : 0.540316 kWh. RAM Power : 23.887279987335205 W
# [codecarbon INFO @ 01:16:43] Energy consumed for all GPUs : 0.477937 kWh. Total GPU Power : 22.2807492771614 W
# [codecarbon INFO @ 01:16:43] Energy consumed for all CPUs : 0.972607 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:16:43] 1.990861 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:16:55] Energy consumed for RAM : 0.539602 kWh. RAM Power : 23.887279987335205 W
# [codecarbon INFO @ 01:16:55] Energy consumed for all GPUs : 0.478601 kWh. Total GPU Power : 21.918245031252187 W
# [codecarbon INFO @ 01:16:55] Energy consumed for all CPUs : 0.972156 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:16:55] 1.990359 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:16:58] Energy consumed for RAM : 0.540416 kWh. RAM Power : 23.887279987335205 W
# [codecarbon INFO @ 01:16:58] Energy consumed for all GPUs : 0.478028 kWh. Total GPU Power : 21.877453743489088 W
# [codecarbon INFO @ 01:16:58] Energy consumed for all CPUs : 0.972784 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:16:58] 1.991228 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:17:10] Energy consumed for RAM : 0.539702 kWh. RAM Power : 23.887279987335205 W
# [codecarbon INFO @ 01:17:10] Energy consumed for all GPUs : 0.478693 kWh. Total GPU Power : 22.053401564707954 W
# [codecarbon INFO @ 01:17:10] Energy consumed for all CPUs : 0.972333 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:17:10] 1.990728 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:17:13] Energy consumed for RAM : 0.540515 kWh. RAM Power : 23.887279987335205 W
# [codecarbon INFO @ 01:17:13] Energy consumed for all GPUs : 0.478120 kWh. Total GPU Power : 21.97683740744745 W
# [codecarbon INFO @ 01:17:13] Energy consumed for all CPUs : 0.972962 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:17:13] 1.991597 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:17:25] Energy consumed for RAM : 0.539801 kWh. RAM Power : 23.887279987335205 W
# [codecarbon INFO @ 01:17:25] Energy consumed for all GPUs : 0.478783 kWh. Total GPU Power : 21.71937105342327 W
# [codecarbon INFO @ 01:17:25] Energy consumed for all CPUs : 0.972510 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:17:25] 1.991095 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:17:28] Energy consumed for RAM : 0.540615 kWh. RAM Power : 23.887279987335205 W
# [codecarbon INFO @ 01:17:28] Energy consumed for all GPUs : 0.478209 kWh. Total GPU Power : 21.45743722643473 W
# [codecarbon INFO @ 01:17:28] Energy consumed for all CPUs : 0.973139 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:17:28] 1.991963 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:17:40] Energy consumed for RAM : 0.539901 kWh. RAM Power : 23.887279987335205 W
# [codecarbon INFO @ 01:17:40] Energy consumed for all GPUs : 0.478884 kWh. Total GPU Power : 24.144786768898992 W
# [codecarbon INFO @ 01:17:40] Energy consumed for all CPUs : 0.972688 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:17:40] 1.991472 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:17:43] Energy consumed for RAM : 0.540714 kWh. RAM Power : 23.887279987335205 W
# [codecarbon INFO @ 01:17:43] Energy consumed for all GPUs : 0.478334 kWh. Total GPU Power : 29.857207306272084 W
# [codecarbon INFO @ 01:17:43] Energy consumed for all CPUs : 0.973316 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:17:43] 1.992364 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:17:55] Energy consumed for RAM : 0.540001 kWh. RAM Power : 23.887279987335205 W
# [codecarbon INFO @ 01:17:55] Energy consumed for all GPUs : 0.478994 kWh. Total GPU Power : 26.405025497849994 W
# [codecarbon INFO @ 01:17:55] Energy consumed for all CPUs : 0.972865 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:17:55] 1.991859 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:17:58] Energy consumed for RAM : 0.540814 kWh. RAM Power : 23.887279987335205 W
# [codecarbon INFO @ 01:17:58] Energy consumed for all GPUs : 0.478420 kWh. Total GPU Power : 20.614003849585863 W
# [codecarbon INFO @ 01:17:58] Energy consumed for all CPUs : 0.973493 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:17:58] 1.992727 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:18:10] Energy consumed for RAM : 0.540100 kWh. RAM Power : 23.887279987335205 W
# [codecarbon INFO @ 01:18:10] Energy consumed for all GPUs : 0.479074 kWh. Total GPU Power : 19.34221109801624 W
# [codecarbon INFO @ 01:18:10] Energy consumed for all CPUs : 0.973042 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:18:10] 1.992216 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:18:13] Energy consumed for RAM : 0.540914 kWh. RAM Power : 23.887279987335205 W
# [codecarbon INFO @ 01:18:13] Energy consumed for all GPUs : 0.478499 kWh. Total GPU Power : 18.87058139706746 W
# [codecarbon INFO @ 01:18:13] Energy consumed for all CPUs : 0.973670 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:18:13] 1.993083 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:18:25] Energy consumed for RAM : 0.540200 kWh. RAM Power : 23.887279987335205 W
# [codecarbon INFO @ 01:18:25] Energy consumed for all GPUs : 0.479158 kWh. Total GPU Power : 20.057053285645413 W
# [codecarbon INFO @ 01:18:25] Energy consumed for all CPUs : 0.973219 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:18:25] 1.992577 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:18:28] Energy consumed for RAM : 0.541013 kWh. RAM Power : 23.887279987335205 W
# [codecarbon INFO @ 01:18:28] Energy consumed for all GPUs : 0.478585 kWh. Total GPU Power : 20.739433647902732 W
# [codecarbon INFO @ 01:18:28] Energy consumed for all CPUs : 0.973848 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:18:28] 1.993446 kWh of electricity used since the beginning.

# %%
data_path='datasets/URL_data.csv'
data = pd.read_csv(data_path)
negative_sample = data.loc[(data['label'] == -1)]
positive_sample = data.loc[(data['label'] == 1)]
url_negative = negative_sample['url']
url = positive_sample['url']
n = len(url)
train_negative = negative_sample.sample(frac = 0.3)

# %%
def get_train_time(num_group_min, num_group_max, c_min, c_max, R_sum,url,n,min_thres,max_thres,train_negative,positive_sample,model):
    if model=='bl':
        bloom_filter = BloomFilter(n, R_sum)
        bloom_filter.insert(url)
        return bloom_filter
    elif model=='disjoint_Ada_BF':
        Bloom_Filters_opt, thresholds_opt, non_empty_ix_opt = disjoint_Ada_BF.Find_Optimal_Parameters(c_min,c_max, num_group_min, 
                                                                   num_group_max, R_sum,
                                                                   train_negative, positive_sample)
        return Bloom_Filters_opt,thresholds_opt,non_empty_ix_opt
    elif model=='learned_BF':
        bloom_filter_opt, thres_opt = learned_Bloom_filter.Find_Optimal_Parameters(max_thres, min_thres, R_sum,
                                                                                     train_negative, positive_sample)
        return bloom_filter_opt,thres_opt
            
    
    elif model=='Ada_BF':
        bloom_filter_opt, thresholds_opt, k_max_opt = Ada_BF.Find_Optimal_Parameters(c_min, c_max, num_group_min,
                                                                                      num_group_max, 
                                                                                      R_sum, train_negative,
                                                                                      positive_sample)
        return bloom_filter_opt, thresholds_opt, k_max_opt
    else:
        return('invalid model, model must be one of bl,disjoint_Ada_BF,learned_BF,Ada_BF')

# %%
def simulation_function(func, *args):
    tracker = EmissionsTracker()
    tracker.start()
    start_time = time.time()
    result = func(*args)  
    end_time = time.time()
    time_elapsed = end_time - start_time
    emissions: float = tracker.stop()
    return time_elapsed, emissions


def simus(func, *args, num_runs=100):
    times = np.zeros(num_runs)
    electricity = np.zeros(num_runs)

    for i in range(num_runs):
        times[i], electricity[i] = simulation_function(func, *args) 

    return pd.DataFrame({'total_time': times, 'electricity': electricity})

def parallel_simus(func, *args, num_runs=100, num_cpus=None):
    with ThreadPoolExecutor(max_workers=num_cpus) as executor:
        results = list(executor.map(lambda _: simulation_function(func, *args), range(num_runs)))

    times, electricity = zip(*results)
    times = np.array(times)
    electricity = np.array(electricity)

    return pd.DataFrame({'total_time': times, 'electricity': electricity})

# %%
# %%capture
##collecting 800 
n_iters=200
args_bl=(8, 12, 1.8, 2.1, 200000,url,n,0.5,0.9,
                           train_negative,positive_sample,'bl')
args_dis_ada=(8, 12, 1.8, 2.1, 200000,url,n,0.5,0.9,
                           train_negative,positive_sample,'disjoint_Ada_BF')
args_lbf=(8, 12, 1.8, 2.1, 200000,url,n,0.5,0.9,
                           train_negative,positive_sample,'learned_BF')
args_ada=(8, 12, 1.8, 2.1, 200000,url,n,0.5,0.9,
                           train_negative,positive_sample,'Ada_BF')
                           
df_bl=simus(get_train_time,*args_bl,num_runs=n_iters)

df_dis_ada=simus(get_train_time,*args_dis_ada,num_runs=n_iters)

df_lbf=simus(get_train_time,*args_lbf,num_runs=n_iters)

df_ada=simus(get_train_time,*args_ada,num_runs=n_iters)

# %%
import os
num_cpu=os.cpu_count()

# %%
# %%capture
df_bl_para=parallel_simus(get_train_time,*args_bl,num_runs=n_iters,num_cpus=num_cpu)

df_dis_ada_para=parallel_simus(get_train_time,*args_dis_ada,num_runs=n_iters,num_cpus=num_cpu)

df_lbf_para=parallel_simus(get_train_time,*args_lbf,num_runs=n_iters,num_cpus=num_cpu)

df_ada_para=parallel_simus(get_train_time,*args_ada,num_runs=n_iters,num_cpus=num_cpu)

# %%
df_bl['method']='bloom_filter'
df_dis_ada['method']='disjoint_Ada_BF'
df_lbf['method']='learned_bf'
df_ada['method']='Ada_BF'

df_bl_para['method']='bloom_filter'
df_dis_ada_para['method']='disjoint_Ada_BF'
df_lbf_para['method']='learned_bf'
df_ada_para['method']='Ada_BF'

# %%
df_bl['running_method']='seq'
df_dis_ada['running_method']='seq'
df_lbf['running_method']='seq'
df_ada['running_method']='seq'

df_bl_para['running_method']='parallel'
df_dis_ada_para['running_method']='parallel'
df_lbf_para['running_method']='parallel'
df_ada_para['running_method']='parallel'

# %%
df_bl['stage']='training'
df_dis_ada['stage']='training'
df_lbf['stage']='training'
df_ada['stage']='training'

df_bl_para['stage']='training'
df_dis_ada_para['stage']='training'
df_lbf_para['stage']='training'
df_ada_para['stage']='training'

# %%
df_all_train=pd.concat([df_bl, df_dis_ada,df_lbf,df_ada,
                        df_bl_para,df_dis_ada_para,df_lbf_para,df_ada_para], ignore_index=True)

# %%
df_all_train
# Out:
#       total_time electricity        method running_method     stage
# 0       0.055638         0.0  bloom_filter            seq  training
# 1       0.067798    0.000001  bloom_filter            seq  training
# 2       0.054271         0.0  bloom_filter            seq  training
# 3       0.056672         0.0  bloom_filter            seq  training
# 4       0.056349         0.0  bloom_filter            seq  training
# ...          ...         ...           ...            ...       ...
# 1595  339.127679        None        Ada_BF       parallel  training
# 1596  229.295153        None        Ada_BF       parallel  training
# 1597  206.562303        None        Ada_BF       parallel  training
# 1598  204.152578        None        Ada_BF       parallel  training
# 1599  207.844182        None        Ada_BF       parallel  training
#
# [1600 rows x 5 columns]

# %%
df_all_train.dropna()
# Out:
#      total_time electricity        method running_method     stage
# 0      0.055638         0.0  bloom_filter            seq  training
# 1      0.067798    0.000001  bloom_filter            seq  training
# 2      0.054271         0.0  bloom_filter            seq  training
# 3      0.056672         0.0  bloom_filter            seq  training
# 4      0.056349         0.0  bloom_filter            seq  training
# ..          ...         ...           ...            ...       ...
# 864    0.120789    0.000001  bloom_filter       parallel  training
# 865    0.080597    0.000001  bloom_filter       parallel  training
# 866    0.248454    0.000002  bloom_filter       parallel  training
# 867    0.609097    0.000004  bloom_filter       parallel  training
# 868    0.190651    0.000002  bloom_filter       parallel  training
#
# [854 rows x 5 columns]

# %%
bloom_filter=get_train_time(8, 12, 1.8, 2.1, 200000,url,n,0.5,0.9,
                           train_negative,positive_sample,model='bl')

Bloom_Filters_opt, thresholds_opt, non_empty_ix_opt=get_train_time(8, 12, 1.8, 2.1, 200000,url,n,0.5,0.9,
                           train_negative,positive_sample,model='disjoint_Ada_BF')

bloom_filter_opt,thres_opt=get_train_time(8, 12, 1.8, 2.1, 200000,url,n,0.5,0.9,
                           train_negative,positive_sample,model='learned_BF')

bloom_filter_opt_ada, thresholds_opt_ada, k_max_opt=get_train_time(8, 12, 1.8, 2.1, 200000,url,n,0.5,0.9,
                           train_negative,positive_sample,model='Ada_BF')
# Out:
# False positive items: 1989, Number of groups: 8, c = 1.800000
# False positive items: 1904, Number of groups: 8, c = 1.900000
# False positive items: 1978, Number of groups: 8, c = 2.000000
# False positive items: 2001, Number of groups: 8, c = 2.100000
# False positive items: 1875, Number of groups: 9, c = 1.800000
# False positive items: 1895, Number of groups: 9, c = 1.900000
# False positive items: 1982, Number of groups: 9, c = 2.000000
# False positive items: 2025, Number of groups: 9, c = 2.100000
# False positive items: 1930, Number of groups: 10, c = 1.800000
# False positive items: 1866, Number of groups: 10, c = 1.900000
# False positive items: 1972, Number of groups: 10, c = 2.000000
# False positive items: 2038, Number of groups: 10, c = 2.100000
# False positive items: 1922, Number of groups: 11, c = 1.800000
# False positive items: 1843, Number of groups: 11, c = 1.900000
# False positive items: 1856, Number of groups: 11, c = 2.000000
# False positive items: 1956, Number of groups: 11, c = 2.100000
# False positive items: 1873, Number of groups: 12, c = 1.800000
# False positive items: 1881, Number of groups: 12, c = 1.900000
# False positive items: 1837, Number of groups: 12, c = 2.000000
# False positive items: 1937, Number of groups: 12, c = 2.100000
# Threshold: 0.500000, False positive items: 3532
# Threshold: 0.510000, False positive items: 3521
# Threshold: 0.520000, False positive items: 3429
# Threshold: 0.530000, False positive items: 3503
# Threshold: 0.540000, False positive items: 3402
# Threshold: 0.550000, False positive items: 3428
# Threshold: 0.560000, False positive items: 3421
# Threshold: 0.570000, False positive items: 3462
# Threshold: 0.580000, False positive items: 3468
# Threshold: 0.590000, False positive items: 3547
# Threshold: 0.600000, False positive items: 3509
# Threshold: 0.610000, False positive items: 3623
# Threshold: 0.620000, False positive items: 3643
# Threshold: 0.630000, False positive items: 3658
# Threshold: 0.640000, False positive items: 3768
# Threshold: 0.650000, False positive items: 3792
# Threshold: 0.660000, False positive items: 3849
# Threshold: 0.670000, False positive items: 4048
# Threshold: 0.680000, False positive items: 4164
# Threshold: 0.690000, False positive items: 4487
# Threshold: 0.700000, False positive items: 4712
# Threshold: 0.710000, False positive items: 4695
# Threshold: 0.720000, False positive items: 4925
# Threshold: 0.730000, False positive items: 5047
# Threshold: 0.740000, False positive items: 5313
# Threshold: 0.750000, False positive items: 5442
# Threshold: 0.760000, False positive items: 5634
# Threshold: 0.770000, False positive items: 6047
# Threshold: 0.780000, False positive items: 6103
# Threshold: 0.790000, False positive items: 6345
# Threshold: 0.800000, False positive items: 6590
# Threshold: 0.810000, False positive items: 7318
# Threshold: 0.820000, False positive items: 7521
# Threshold: 0.830000, False positive items: 7756
# Threshold: 0.840000, False positive items: 8143
# Threshold: 0.850000, False positive items: 8276
# Threshold: 0.860000, False positive items: 8703
# Threshold: 0.870000, False positive items: 8570
# Threshold: 0.880000, False positive items: 9061
# Threshold: 0.890000, False positive items: 9499
# Threshold: 0.900000, False positive items: 9837
# False positive items: 1937, Number of groups: 8, c = 1.800000
# False positive items: 1894, Number of groups: 8, c = 1.900000
# False positive items: 2084, Number of groups: 8, c = 2.000000
# False positive items: 2175, Number of groups: 8, c = 2.100000
# False positive items: 1995, Number of groups: 9, c = 1.800000
# False positive items: 2426, Number of groups: 9, c = 1.900000
# False positive items: 2920, Number of groups: 9, c = 2.000000
# False positive items: 3063, Number of groups: 9, c = 2.100000
# False positive items: 2478, Number of groups: 10, c = 1.800000
# False positive items: 3331, Number of groups: 10, c = 1.900000
# False positive items: 4390, Number of groups: 10, c = 2.000000
# False positive items: 5058, Number of groups: 10, c = 2.100000
# False positive items: 3557, Number of groups: 11, c = 1.800000
# False positive items: 4970, Number of groups: 11, c = 1.900000
# False positive items: 6579, Number of groups: 11, c = 2.000000
# False positive items: 7533, Number of groups: 11, c = 2.100000
# False positive items: 5512, Number of groups: 12, c = 1.800000
# False positive items: 7676, Number of groups: 12, c = 1.900000
# False positive items: 10033, Number of groups: 12, c = 2.000000
# False positive items: 11320, Number of groups: 12, c = 2.100000

# %%
def get_testing_time(data,bloom_filter,Bloom_Filters_opt,
                     thresholds_opt,non_empty_ix_opt,bloom_filter_opt,
                    thres_opt,bloom_filter_opt_ada,thresholds_opt_ada,k_max_opt,model):
    
    if model=='bl':
        negative_sample = data.loc[(data['label']==-1)]
        url_negative = negative_sample['url']
        n1 = bloom_filter.test(url_negative, single_key=False)
        print('False positive items: ', sum(n1))
        
    elif model=='disjoint_Ada_BF':
        negative_sample = data.loc[(data['label']==-1)]
        ML_positive = negative_sample.loc[(negative_sample['score'] >= thresholds_opt[-2]), 'url']
        url_negative = negative_sample.loc[(negative_sample['score'] < thresholds_opt[-2]), 'url']
        score_negative = negative_sample.loc[(negative_sample['score'] < thresholds_opt[-2]), 'score']
        test_result = np.zeros(len(url_negative))
        ss = 0
        for score_s, url_s in zip(score_negative, url_negative):
            ix = min(np.where(score_s < thresholds_opt)[0]) - 1
            if ix >= non_empty_ix_opt:
                test_result[ss] = Bloom_Filters_opt[ix].test(url_s)
            else:
                test_result[ss] = 0
            ss += 1
        FP_items = sum(test_result) + len(ML_positive)
        FPR = FP_items/len(url_negative)
        print('False positive items: {}; FPR: {}; Size of quries: {}'.format(FP_items, FPR, len(url_negative)))
        
    elif model=='learned_BF':
        negative_sample = data.loc[(data['label']==-1)]
        ML_positive = negative_sample.loc[(negative_sample['score'] > thres_opt), 'url']
        bloom_negative = negative_sample.loc[(negative_sample['score'] <= thres_opt), 'url']
        score_negative = negative_sample.loc[(negative_sample['score'] < thres_opt), 'score']
        BF_positive = bloom_filter_opt.test(bloom_negative, single_key = False)
        FP_items = sum(BF_positive) + len(ML_positive)
        print('False positive items: %d' % FP_items)

    elif model=='Ada_BF':
        negative_sample = data.loc[(data['label']==-1)]
        ML_positive = negative_sample.loc[(negative_sample['score'] >= thresholds_opt_ada[-2]), 'url']
        url_negative = negative_sample.loc[(negative_sample['score'] < thresholds_opt_ada[-2]), 'url']
        score_negative = negative_sample.loc[(negative_sample['score'] < thresholds_opt_ada[-2]), 'score']
        test_result = np.zeros(len(url_negative))
        ss = 0
        for score_s, url_s in zip(score_negative, url_negative):
            ix = min(np.where(score_s < thresholds_opt_ada)[0])
            # thres = thresholds[ix]
            k = k_max_opt - ix
            test_result[ss] = bloom_filter_opt_ada.test(url_s, k)
            ss += 1
        FP_items = sum(test_result) + len(ML_positive)
        print('False positive items: %d' % FP_items)
       
    else:
        return('invalid model, model must be one of bl,disjoint_Ada_BF,learned_BF,Ada_BF')

# %%
# %%capture
##collecting 800 
func_args_bl = (data, bloom_filter, Bloom_Filters_opt, thresholds_opt, non_empty_ix_opt,
                bloom_filter_opt, thres_opt, bloom_filter_opt_ada, thresholds_opt_ada,
                k_max_opt, 'bl')
func_args_dis_ada= (data, bloom_filter, Bloom_Filters_opt, thresholds_opt, non_empty_ix_opt,
                bloom_filter_opt, thres_opt, bloom_filter_opt_ada, thresholds_opt_ada,
                k_max_opt, 'disjoint_Ada_BF')
func_args_lbf= (data, bloom_filter, Bloom_Filters_opt, thresholds_opt, non_empty_ix_opt,
                bloom_filter_opt, thres_opt, bloom_filter_opt_ada, thresholds_opt_ada,
                k_max_opt, 'learned_BF')
func_args_ada = (data, bloom_filter, Bloom_Filters_opt, thresholds_opt, non_empty_ix_opt,
                bloom_filter_opt, thres_opt, bloom_filter_opt_ada, thresholds_opt_ada,
                k_max_opt, 'Ada_BF')

df_bl_test=simus(get_testing_time, *func_args_bl, num_runs=n_iters)

df_dis_ada_test=simus(get_testing_time,*func_args_dis_ada,num_runs=n_iters)

df_lbf_test=simus(get_testing_time,*func_args_lbf,num_runs=n_iters)

df_ada_test=simus(get_testing_time,*func_args_ada,num_runs=n_iters)



df_bl_test_para=parallel_simus(get_testing_time,*func_args_bl,num_runs=n_iters,num_cpus=num_cpu)

df_dis_ada_test_para=parallel_simus(get_testing_time,*func_args_bl,num_runs=n_iters,num_cpus=num_cpu)

df_lbf_test_para=parallel_simus(get_testing_time,*func_args_dis_ada,num_runs=n_iters,num_cpus=num_cpu)

df_ada_test_para=parallel_simus(get_testing_time,*func_args_ada,num_runs=n_iters,num_cpus=num_cpu)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File d:\anaconda\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# TimeoutError: timed out
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Desktop\repos\Bloom-Filter-Carbon-Footprint\carbon_gpu_bl.ipynb Cell 15 line 1
#       <a href='vscode-notebook-cell:/d%3A/Desktop/repos/Bloom-Filter-Carbon-Footprint/carbon_gpu_bl.ipynb#X21sZmlsZQ%3D%3D?line=7'>8</a> func_args_lbf= (data, bloom_filter, Bloom_Filters_opt, thresholds_opt, non_empty_ix_opt,
#       <a href='vscode-notebook-cell:/d%3A/Desktop/repos/Bloom-Filter-Carbon-Footprint/carbon_gpu_bl.ipynb#X21sZmlsZQ%3D%3D?line=8'>9</a>                 bloom_filter_opt, thres_opt, bloom_filter_opt_ada, thresholds_opt_ada,
#      <a href='vscode-notebook-cell:/d%3A/Desktop/repos/Bloom-Filter-Carbon-Footprint/carbon_gpu_bl.ipynb#X21sZmlsZQ%3D%3D?line=9'>10</a>                 k_max_opt, 'learned_BF')
#      <a href='vscode-notebook-cell:/d%3A/Desktop/repos/Bloom-Filter-Carbon-Footprint/carbon_gpu_bl.ipynb#X21sZmlsZQ%3D%3D?line=10'>11</a> func_args_ada = (data, bloom_filter, Bloom_Filters_opt, thresholds_opt, non_empty_ix_opt,
#      <a href='vscode-notebook-cell:/d%3A/Desktop/repos/Bloom-Filter-Carbon-Footprint/carbon_gpu_bl.ipynb#X21sZmlsZQ%3D%3D?line=11'>12</a>                 bloom_filter_opt, thres_opt, bloom_filter_opt_ada, thresholds_opt_ada,
#      <a href='vscode-notebook-cell:/d%3A/Desktop/repos/Bloom-Filter-Carbon-Footprint/carbon_gpu_bl.ipynb#X21sZmlsZQ%3D%3D?line=12'>13</a>                 k_max_opt, 'Ada_BF')
# ---> <a href='vscode-notebook-cell:/d%3A/Desktop/repos/Bloom-Filter-Carbon-Footprint/carbon_gpu_bl.ipynb#X21sZmlsZQ%3D%3D?line=14'>15</a> df_bl_test=simus(get_testing_time, *func_args_bl, num_runs=n_iters)
#      <a href='vscode-notebook-cell:/d%3A/Desktop/repos/Bloom-Filter-Carbon-Footprint/carbon_gpu_bl.ipynb#X21sZmlsZQ%3D%3D?line=16'>17</a> df_dis_ada_test=simus(get_testing_time,*func_args_dis_ada,num_runs=n_iters)
#      <a href='vscode-notebook-cell:/d%3A/Desktop/repos/Bloom-Filter-Carbon-Footprint/carbon_gpu_bl.ipynb#X21sZmlsZQ%3D%3D?line=18'>19</a> df_lbf_test=simus(get_testing_time,*func_args_lbf,num_runs=n_iters)
#
# d:\Desktop\repos\Bloom-Filter-Carbon-Footprint\carbon_gpu_bl.ipynb Cell 15 line 1
#      <a href='vscode-notebook-cell:/d%3A/Desktop/repos/Bloom-Filter-Carbon-Footprint/carbon_gpu_bl.ipynb#X21sZmlsZQ%3D%3D?line=13'>14</a> electricity = np.zeros(num_runs)
#      <a href='vscode-notebook-cell:/d%3A/Desktop/repos/Bloom-Filter-Carbon-Footprint/carbon_gpu_bl.ipynb#X21sZmlsZQ%3D%3D?line=15'>16</a> for i in range(num_runs):
# ---> <a href='vscode-notebook-cell:/d%3A/Desktop/repos/Bloom-Filter-Carbon-Footprint/carbon_gpu_bl.ipynb#X21sZmlsZQ%3D%3D?line=16'>17</a>     times[i], electricity[i] = simulation_function(func, *args)
#      <a href='vscode-notebook-cell:/d%3A/Desktop/repos/Bloom-Filter-Carbon-Footprint/carbon_gpu_bl.ipynb#X21sZmlsZQ%3D%3D?line=18'>19</a> return pd.DataFrame({'total_time': times, 'electricity': electricity})
#
# d:\Desktop\repos\Bloom-Filter-Carbon-Footprint\carbon_gpu_bl.ipynb Cell 15 line 2
#       <a href='vscode-notebook-cell:/d%3A/Desktop/repos/Bloom-Filter-Carbon-Footprint/carbon_gpu_bl.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> def simulation_function(func, *args):
# ----> <a href='vscode-notebook-cell:/d%3A/Desktop/repos/Bloom-Filter-Carbon-Footprint/carbon_gpu_bl.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a>     tracker = EmissionsTracker()
#       <a href='vscode-notebook-cell:/d%3A/Desktop/repos/Bloom-Filter-Carbon-Footprint/carbon_gpu_bl.ipynb#X21sZmlsZQ%3D%3D?line=2'>3</a>     tracker.start()
#       <a href='vscode-notebook-cell:/d%3A/Desktop/repos/Bloom-Filter-Carbon-Footprint/carbon_gpu_bl.ipynb#X21sZmlsZQ%3D%3D?line=3'>4</a>     start_time = time.time()
#
# File d:\anaconda\Lib\site-packages\codecarbon\emissions_tracker.py:352, in BaseEmissionsTracker.__init__(self, project_name, measure_power_secs, api_call_interval, api_endpoint, api_key, output_dir, output_file, save_to_file, save_to_api, save_to_logger, logging_logger, save_to_prometheus, prometheus_url, gpu_ids, emissions_endpoint, experiment_id, experiment_name, co2_signal_api_token, tracking_mode, log_level, on_csv_write, logger_preamble, default_cpu_power, pue)
#     345 self._scheduler = PeriodicScheduler(
#     346     function=self._measure_power_and_energy,
#     347     interval=self._measure_power_secs,
#     348 )
#     350 self._data_source = DataSource()
# --> 352 cloud: CloudMetadata = self._get_cloud_metadata()
#     354 if cloud.is_on_private_infra:
#     355     self._geo = self._get_geo_metadata()
#
# File d:\anaconda\Lib\site-packages\codecarbon\emissions_tracker.py:840, in EmissionsTracker._get_cloud_metadata(self)
#     838 def _get_cloud_metadata(self) -> CloudMetadata:
#     839     if self._cloud is None:
# --> 840         self._cloud = CloudMetadata.from_utils()
#     841     return self._cloud
#
# File d:\anaconda\Lib\site-packages\codecarbon\external\geography.py:39, in CloudMetadata.from_utils(cls)
#      31     return re.search(google_region_regex, zone).group(0)
#      33 extract_region_for_provider: Dict[str, Callable] = {
#      34     "aws": lambda x: x["metadata"]["region"],
#      35     "azure": lambda x: x["metadata"]["compute"]["location"],
#      36     "gcp": lambda x: extract_gcp_region(x["metadata"]["zone"]),
#      37 }
# ---> 39 cloud_metadata: Dict = get_env_cloud_details()
#      41 if cloud_metadata is None:
#      42     return cls(provider=None, region=None)
#
# File d:\anaconda\Lib\site-packages\codecarbon\core\cloud.py:80, in get_env_cloud_details(timeout)
#      78 try:
#      79     params = CLOUD_METADATA_MAPPING[provider]
# ---> 80     response = requests.get(
#      81         params["url"], headers=params["headers"], timeout=timeout
#      82     )
#      83     response.raise_for_status()
#      84     response_data = response.json()
#
# File d:\anaconda\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File d:\anaconda\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File d:\anaconda\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File d:\anaconda\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File d:\anaconda\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File d:\anaconda\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File d:\anaconda\Lib\site-packages\urllib3\connectionpool.py:415, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     413         conn.request_chunked(method, url, **httplib_request_kw)
#     414     else:
# --> 415         conn.request(method, url, **httplib_request_kw)
#     417 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     418 # legitimately able to close the connection after sending a valid response.
#     419 # With this behaviour, the received response is still readable.
#     420 except BrokenPipeError:
#     421     # Python 3
#
# File d:\anaconda\Lib\site-packages\urllib3\connection.py:244, in HTTPConnection.request(self, method, url, body, headers)
#     242 if "user-agent" not in (six.ensure_str(k.lower()) for k in headers):
#     243     headers["User-Agent"] = _get_default_user_agent()
# --> 244 super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#
# File d:\anaconda\Lib\http\client.py:1286, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1283 def request(self, method, url, body=None, headers={}, *,
#    1284             encode_chunked=False):
#    1285     """Send a complete request to the server."""
# -> 1286     self._send_request(method, url, body, headers, encode_chunked)
#
# File d:\anaconda\Lib\http\client.py:1332, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1328 if isinstance(body, str):
#    1329     # RFC 2616 Section 3.7.1 says that text default has a
#    1330     # default charset of iso-8859-1.
#    1331     body = _encode(body, 'body')
# -> 1332 self.endheaders(body, encode_chunked=encode_chunked)
#
# File d:\anaconda\Lib\http\client.py:1281, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1279 else:
#    1280     raise CannotSendHeader()
# -> 1281 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File d:\anaconda\Lib\http\client.py:1041, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1039 msg = b"\r\n".join(self._buffer)
#    1040 del self._buffer[:]
# -> 1041 self.send(msg)
#    1043 if message_body is not None:
#    1044
#    1045     # create a consistent interface to message_body
#    1046     if hasattr(message_body, 'read'):
#    1047         # Let file-like take precedence over byte-like.  This
#    1048         # is needed to allow the current position of mmap'ed
#    1049         # files to be taken into account.
#
# File d:\anaconda\Lib\http\client.py:979, in HTTPConnection.send(self, data)
#     977 if self.sock is None:
#     978     if self.auto_open:
# --> 979         self.connect()
#     980     else:
#     981         raise NotConnected()
#
# File d:\anaconda\Lib\site-packages\urllib3\connection.py:205, in HTTPConnection.connect(self)
#     204 def connect(self):
# --> 205     conn = self._new_conn()
#     206     self._prepare_conn(conn)
#
# File d:\anaconda\Lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     171     extra_kw["socket_options"] = self.socket_options
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#     179     raise ConnectTimeoutError(
#     180         self,
#     181         "Connection to %s timed out. (connect timeout=%s)"
#     182         % (self.host, self.timeout),
#     183     )
#
# File d:\anaconda\Lib\site-packages\urllib3\util\connection.py:91, in create_connection(address, timeout, source_address, socket_options)
#      89         err = e
#      90         if sock is not None:
# ---> 91             sock.close()
#      92             sock = None
#      94 if err is not None:
#
# File d:\anaconda\Lib\socket.py:499, in socket.close(self)
#     495 def _real_close(self, _ss=_socket.socket):
#     496     # This function should not reference any globals. See issue #808164.
#     497     _ss.close(self)
# --> 499 def close(self):
#     500     # This function should not reference any globals. See issue #808164.
#     501     self._closed = True
#     502     if self._io_refs <= 0:
#
# KeyboardInterrupt:

# %%
df_bl_test['method']='bloom_filter'
df_dis_ada_test['method']='disjoint_Ada_BF'
df_lbf_test['method']='learned_bf'
df_ada_test['method']='Ada_BF'

df_bl_test_para['method']='bloom_filter'
df_dis_ada_test_para['method']='disjoint_Ada_BF'
df_lbf_test_para['method']='learned_bf'
df_ada_test_para['method']='Ada_BF'

# %%
df_bl_test['running_method']='seq'
df_dis_ada_test['running_method']='seq'
df_lbf_test['running_method']='seq'
df_ada_test['running_method']='seq'

df_bl_test_para['running_method']='parallel'
df_dis_ada_test_para['running_method']='parallel'
df_lbf_test_para['running_method']='parallel'
df_ada_test_para['running_method']='parallel'

# %%
df_bl_test['stage']='test'
df_dis_ada_test['stage']='test'
df_lbf_test['stage']='test'
df_ada_test['stage']='test'

df_bl_test_para['stage']='test'
df_dis_ada_test_para['stage']='test'
df_lbf_test_para['stage']='test'
df_ada_test_para['stage']='test'

# %%
df_all_test=pd.concat([df_bl_test, df_dis_ada_test,df_lbf_test,df_ada_test,
                      df_bl_test_para,df_dis_ada_test_para,df_lbf_test_para,df_ada_test_para], ignore_index=True)

# %%
df_all_test
# Out:
#    total_time  electricity           method running_method stage
# 0    0.854022     0.000004     bloom_filter            seq  test
# 1    3.484040     0.000018  disjoint_Ada_BF            seq  test
# 2    2.215681     0.000011       learned_bf            seq  test
# 3    3.362883     0.000017           Ada_BF            seq  test
# 4    0.876784     0.000005     bloom_filter       parallel  test
# 5    0.901590     0.000005  disjoint_Ada_BF       parallel  test
# 6    3.645699     0.000019       learned_bf       parallel  test
# 7    3.337062     0.000017           Ada_BF       parallel  test

# %%
df_all=pd.concat([df_all_train,df_all_test], ignore_index=True)
df_all
# Out:
#       total_time electricity        method running_method     stage
# 0       0.005812         0.0  bloom_filter            seq  training
# 1       0.008353         0.0  bloom_filter            seq  training
# 2       0.000000         NaN  bloom_filter            seq  training
# 3       0.002000         0.0  bloom_filter            seq  training
# 4       0.000000         0.0  bloom_filter            seq  training
# ...          ...         ...           ...            ...       ...
# 3195    0.004940         NaN        Ada_BF       parallel      test
# 3196    0.004093         NaN        Ada_BF       parallel      test
# 3197    0.013877         NaN        Ada_BF       parallel      test
# 3198    0.000000         NaN        Ada_BF       parallel      test
# 3199    0.000000         NaN        Ada_BF       parallel      test
#
# [3200 rows x 5 columns]

# %%
df_all['running']='gpu'
df_all.to_csv('emissions_bl_gpu.csv', index=False)
